# %% [markdown]
# # Cluster Analysis on Prison Cases By State

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Data Preprocessing

# %%
# Read in population data and fillna using OLS
pop = pd.read_csv('clean_data/population.csv').drop(['prison_pop_date','staff_pop_date','abbreviation'], 1)

# Fillin the nan values using a linear model
from sklearn.linear_model import LinearRegression
train = pop[pop['staff_pop']>0].copy()
test = pop[pop['staff_pop'].isna()].copy()
X_train, X_test, y_train = train[['prison_pop']], test[['prison_pop']], train['staff_pop']
ols = LinearRegression().fit(X_train, y_train)
y_pred = ols.predict(X_test)
y_pred = list(map(int, y_pred))
pop.loc[pop['staff_pop'].isnull(), 'staff_pop'] = y_pred

pop.head()
# Out:
#          name  prison_pop  staff_pop
# 0     Alabama       21154     6259.0
# 1      Alaska        4997     1971.0
# 2     Arizona       41674     8536.0
# 3    Arkansas       18181     4045.0
# 4  California      118466    46000.0

# %%
''' define_awareness aims at better categorized the noisy data, 
    higher value means higher administrative awareness,
    7 stands for an estimated R0 (rate of disease Transmission), 
    prisons with extensive number of testing is the highest ranks "3",
    prisons with prisoner testings and staff testings ranks "2",
    prisons with only prisoner testing information ranks "1".
    prison with no testings information ranks "0".
    Notes:Due to the limitation of this dataset, NaN does not necessrily 
    stands for no tests has been conducted, but more likely no information
    has been released to public. However, limited information released during 
    COVID could mean that the shortage in administration.'''

def define_awareness(row):
    if (row['prisoner_tests']+row['staff_tests'])/(row['total_prisoner_cases']+row['total_staff_cases']) > 7 :
        val = 3
    elif row['prisoner_tests']>0 and row['staff_tests']>0 :
        val = 2
    elif row['prisoner_tests']>0 :
        val = 1
    else:
        val = 0
    return val

# %%
# Read in covid cases data and handle 
df = pd.read_csv('data/covid_prison_cases.csv')

# Generate New Feature for Staff_tests
df['date'] = pd.to_datetime(df['as_of_date'])
df = df.set_index('date', drop= 1).drop(['notes','as_of_date','abbreviation'], 1)

# %%
# Check on most recent staticstic
lately_covid = []
for state in df.name.unique():
    lately_covid.append(df[df['name'] == state].iloc[0])
    
lately_covid = pd.DataFrame(lately_covid).set_index('name',drop=1)
#lately_covid['has_staff_death'] = np.where(lately_covid.total_staff_deaths != 0, 1, 0)  
#lately_covid['has_prn_death'] = np.where(lately_covid.total_prisoner_deaths != 0, 1, 0)  
#lately_covid['testing_awearness'] = lately_covid.apply(define_awareness,1)
#lately_covid = lately_covid.drop(['staff_tests','total_staff_deaths'],1)
lately_covid.head()
# Out:
#             staff_tests  prisoner_tests  total_staff_cases  \
# name
# Alabama             NaN           102.0               17.0
# Alaska              NaN           235.0                8.0
# Arizona             NaN           277.0               52.0
# Arkansas            NaN             NaN              127.0
# California          NaN          1551.0              169.0
#
#             total_prisoner_cases  total_staff_deaths  total_prisoner_deaths
# name
# Alabama                      8.0                 0.0                    1.0
# Alaska                       1.0                 0.0                    0.0
# Arizona                     69.0                 0.0                    5.0
# Arkansas                   944.0                 0.0                    5.0
# California                 398.0                 0.0                    1.0

# %%
lately_covid['total_staff_deaths'].fillna(0, inplace=True)
lately_covid['total_prisoner_deaths'].fillna(0, inplace=True)

# %%
lately_covid
# Out:
#                 staff_tests  prisoner_tests  total_staff_cases  \
# name
# Alabama                 NaN           102.0               17.0
# Alaska                  NaN           235.0                8.0
# Arizona                 NaN           277.0               52.0
# Arkansas                NaN             NaN              127.0
# California              NaN          1551.0              169.0
# Colorado                NaN          1067.0               25.0
# Connecticut             NaN             NaN              358.0
# Delaware              301.0           267.0               64.0
# Florida                 NaN           805.0              180.0
# Georgia                 NaN             NaN              100.0
# Hawaii                  NaN            20.0                0.0
# Idaho                  68.0            47.0                5.0
# Illinois                NaN           600.0              157.0
# Indiana               889.0           844.0              234.0
# Iowa                    NaN           433.0               11.0
# Kansas                  NaN             NaN               96.0
# Kentucky                NaN             NaN               51.0
# Louisiana               NaN             NaN              120.0
# Maine                   NaN            23.0                1.0
# Maryland                NaN             NaN              183.0
# Massachusetts           NaN          1906.0              151.0
# Michigan                NaN          8113.0              293.0
# Minnesota               NaN           428.0               43.0
# Mississippi            43.0            37.0                7.0
# Missouri                NaN           380.0               20.0
# Montana                 NaN             NaN                3.0
# Nebraska                NaN             NaN                5.0
# Nevada                  NaN            49.0               16.0
# New Hampshire           NaN            13.0               11.0
# New Jersey              NaN           276.0              575.0
# New Mexico             64.0            14.0                4.0
# New York                NaN           619.0             1143.0
# North Carolina        250.0          1234.0               29.0
# North Dakota          116.0            32.0                3.0
# Ohio                    NaN          6922.0              483.0
# Oklahoma                NaN          1034.0                9.0
# Oregon                  NaN           243.0               21.0
# Pennsylvania          411.0           327.0              127.0
# Rhode Island          200.0           110.0               11.0
# South Carolina          NaN             NaN               56.0
# South Dakota           47.0            82.0                4.0
# Tennessee               NaN          5962.0               55.0
# Texas                2379.0          2134.0              504.0
# Utah                    NaN           101.0                4.0
# Vermont               154.0           384.0               19.0
# Virginia                NaN             NaN               65.0
# Washington              NaN           350.0               35.0
# West Virginia           NaN            34.0                1.0
# Wisconsin               NaN           155.0               23.0
# Wyoming                12.0            19.0                1.0
# Federal                 NaN             NaN              514.0
#
#                 total_prisoner_cases  total_staff_deaths  \
# name
# Alabama                          8.0                 0.0
# Alaska                           1.0                 0.0
# Arizona                         69.0                 0.0
# Arkansas                       944.0                 0.0
# California                     398.0                 0.0
# Colorado                       310.0                 0.0
# Connecticut                    478.0                 0.0
# Delaware                       125.0                 0.0
# Florida                        393.0                 0.0
# Georgia                        316.0                 1.0
# Hawaii                           0.0                 0.0
# Idaho                            0.0                 0.0
# Illinois                       176.0                 0.0
# Indiana                        500.0                 2.0
# Iowa                            21.0                 0.0
# Kansas                         615.0                 0.0
# Kentucky                       340.0                 0.0
# Louisiana                      338.0                 3.0
# Maine                            0.0                 0.0
# Maryland                        61.0                 0.0
# Massachusetts                  351.0                 0.0
# Michigan                      2073.0                 2.0
# Minnesota                       83.0                 0.0
# Mississippi                      4.0                 0.0
# Missouri                        32.0                 0.0
# Montana                          2.0                 0.0
# Nebraska                         0.0                 0.0
# Nevada                           0.0                 0.0
# New Hampshire                    0.0                 0.0
# New Jersey                     215.0                 2.0
# New Mexico                       0.0                 0.0
# New York                       415.0                 4.0
# North Carolina                 627.0                 0.0
# North Dakota                     0.0                 0.0
# Ohio                          4312.0                 2.0
# Oklahoma                         2.0                 0.0
# Oregon                          44.0                 0.0
# Pennsylvania                   143.0                 0.0
# Rhode Island                     4.0                 0.0
# South Carolina                  42.0                 1.0
# South Dakota                     2.0                 0.0
# Tennessee                     1959.0                 0.0
# Texas                         1336.0                 5.0
# Utah                            10.0                 0.0
# Vermont                         45.0                 0.0
# Virginia                       580.0                 0.0
# Washington                      24.0                 0.0
# West Virginia                    0.0                 0.0
# Wisconsin                       20.0                 0.0
# Wyoming                          0.0                 0.0
# Federal                       2701.0                 0.0
#
#                 total_prisoner_deaths
# name
# Alabama                           1.0
# Alaska                            0.0
# Arizona                           5.0
# Arkansas                          5.0
# California                        1.0
# Colorado                          1.0
# Connecticut                       6.0
# Delaware                          3.0
# Florida                           7.0
# Georgia                          10.0
# Hawaii                            0.0
# Idaho                             0.0
# Illinois                         12.0
# Indiana                          13.0
# Iowa                              0.0
# Kansas                            3.0
# Kentucky                          2.0
# Louisiana                         4.0
# Maine                             0.0
# Maryland                          2.0
# Massachusetts                     7.0
# Michigan                         47.0
# Minnesota                         0.0
# Mississippi                       1.0
# Missouri                          1.0
# Montana                           0.0
# Nebraska                          0.0
# Nevada                            0.0
# New Hampshire                     0.0
# New Jersey                       38.0
# New Mexico                        0.0
# New York                         15.0
# North Carolina                    4.0
# North Dakota                      0.0
# Ohio                             42.0
# Oklahoma                          0.0
# Oregon                            0.0
# Pennsylvania                      3.0
# Rhode Island                      0.0
# South Carolina                    2.0
# South Dakota                      0.0
# Tennessee                         1.0
# Texas                            23.0
# Utah                              0.0
# Vermont                           0.0
# Virginia                          3.0
# Washington                        0.0
# West Virginia                     0.0
# Wisconsin                         0.0
# Wyoming                           0.0
# Federal                          42.0

# %%
prison_covid = pop.merge(lately_covid,on='name').set_index('name')
prison_covid.head()
# Out:
#             prison_pop  staff_pop  staff_tests  prisoner_tests  \
# name
# Alabama          21154     6259.0          NaN           102.0
# Alaska            4997     1971.0          NaN           235.0
# Arizona          41674     8536.0          NaN           277.0
# Arkansas         18181     4045.0          NaN             NaN
# California      118466    46000.0          NaN          1551.0
#
#             total_staff_cases  total_prisoner_cases  total_staff_deaths  \
# name
# Alabama                  17.0                   8.0                 0.0
# Alaska                    8.0                   1.0                 0.0
# Arizona                  52.0                  69.0                 0.0
# Arkansas                127.0                 944.0                 0.0
# California              169.0                 398.0                 0.0
#
#             total_prisoner_deaths
# name
# Alabama                       1.0
# Alaska                        0.0
# Arizona                       5.0
# Arkansas                      5.0
# California                    1.0

# %%
prison_covid
# Out:
#                 prison_pop  staff_pop  staff_tests  prisoner_tests  \
# name
# Alabama              21154     6259.0          NaN           102.0
# Alaska                4997     1971.0          NaN           235.0
# Arizona              41674     8536.0          NaN           277.0
# Arkansas             18181     4045.0          NaN             NaN
# California          118466    46000.0          NaN          1551.0
# Colorado             17412     6267.0          NaN          1067.0
# Connecticut          12218     6170.0          NaN             NaN
# Delaware              4624     2530.0        301.0           267.0
# Florida              91828    22218.0          NaN           805.0
# Georgia              54723     8399.0          NaN             NaN
# Hawaii                4631     1878.0          NaN            20.0
# Idaho                 7641     1999.0         68.0            47.0
# Illinois             36904    11781.0          NaN           600.0
# Indiana              26891     6000.0        889.0           844.0
# Iowa                  8401     2470.0          NaN           433.0
# Kansas                9890     3228.0          NaN             NaN
# Kentucky             11782     3706.0          NaN             NaN
# Louisiana            31609     4857.0          NaN             NaN
# Maine                 2019     1131.0          NaN            23.0
# Maryland             18800     5501.0          NaN             NaN
# Massachusetts         8173     4679.0          NaN          1906.0
# Michigan             37687    11963.0          NaN          8113.0
# Minnesota             8637     1987.0          NaN           428.0
# Mississippi          18669      591.0         43.0            37.0
# Missouri             26000    11000.0          NaN           380.0
# Montana              17355     5131.0          NaN             NaN
# Nebraska              5597     2091.0          NaN             NaN
# Nevada               12451     2800.0          NaN            49.0
# New Hampshire         2433      823.0          NaN            13.0
# New Jersey           18093     8012.0          NaN           276.0
# New Mexico            6588     1893.0         64.0            14.0
# New York             42784    19123.0          NaN           619.0
# North Carolina       33790     7774.0        250.0          1234.0
# North Dakota          1244      282.0        116.0            32.0
# Ohio                 48765    12192.0          NaN          6922.0
# Oklahoma             24408     4290.0          NaN          1034.0
# Oregon               14458     4644.0          NaN           243.0
# Pennsylvania         44098    15073.0        411.0           327.0
# Rhode Island          2289     1339.0        200.0           110.0
# South Carolina       17772     4825.0          NaN             NaN
# South Dakota          3713      599.0         47.0            82.0
# Tennessee            21150     5179.0          NaN          5962.0
# Texas               140124    36073.0       2379.0          2134.0
# Utah                  6131     2261.0          NaN           101.0
# Vermont               1406     1001.0        154.0           384.0
# Virginia             28559     8895.0          NaN             NaN
# Washington           16950     8806.0          NaN           350.0
# West Virginia         5148     1506.0          NaN            34.0
# Wisconsin            22594     4640.0          NaN           155.0
# Wyoming               2486     1029.0         12.0            19.0
# Federal             172349    36607.0          NaN             NaN
#
#                 total_staff_cases  total_prisoner_cases  total_staff_deaths  \
# name
# Alabama                      17.0                   8.0                 0.0
# Alaska                        8.0                   1.0                 0.0
# Arizona                      52.0                  69.0                 0.0
# Arkansas                    127.0                 944.0                 0.0
# California                  169.0                 398.0                 0.0
# Colorado                     25.0                 310.0                 0.0
# Connecticut                 358.0                 478.0                 0.0
# Delaware                     64.0                 125.0                 0.0
# Florida                     180.0                 393.0                 0.0
# Georgia                     100.0                 316.0                 1.0
# Hawaii                        0.0                   0.0                 0.0
# Idaho                         5.0                   0.0                 0.0
# Illinois                    157.0                 176.0                 0.0
# Indiana                     234.0                 500.0                 2.0
# Iowa                         11.0                  21.0                 0.0
# Kansas                       96.0                 615.0                 0.0
# Kentucky                     51.0                 340.0                 0.0
# Louisiana                   120.0                 338.0                 3.0
# Maine                         1.0                   0.0                 0.0
# Maryland                    183.0                  61.0                 0.0
# Massachusetts               151.0                 351.0                 0.0
# Michigan                    293.0                2073.0                 2.0
# Minnesota                    43.0                  83.0                 0.0
# Mississippi                   7.0                   4.0                 0.0
# Missouri                     20.0                  32.0                 0.0
# Montana                       3.0                   2.0                 0.0
# Nebraska                      5.0                   0.0                 0.0
# Nevada                       16.0                   0.0                 0.0
# New Hampshire                11.0                   0.0                 0.0
# New Jersey                  575.0                 215.0                 2.0
# New Mexico                    4.0                   0.0                 0.0
# New York                   1143.0                 415.0                 4.0
# North Carolina               29.0                 627.0                 0.0
# North Dakota                  3.0                   0.0                 0.0
# Ohio                        483.0                4312.0                 2.0
# Oklahoma                      9.0                   2.0                 0.0
# Oregon                       21.0                  44.0                 0.0
# Pennsylvania                127.0                 143.0                 0.0
# Rhode Island                 11.0                   4.0                 0.0
# South Carolina               56.0                  42.0                 1.0
# South Dakota                  4.0                   2.0                 0.0
# Tennessee                    55.0                1959.0                 0.0
# Texas                       504.0                1336.0                 5.0
# Utah                          4.0                  10.0                 0.0
# Vermont                      19.0                  45.0                 0.0
# Virginia                     65.0                 580.0                 0.0
# Washington                   35.0                  24.0                 0.0
# West Virginia                 1.0                   0.0                 0.0
# Wisconsin                    23.0                  20.0                 0.0
# Wyoming                       1.0                   0.0                 0.0
# Federal                     514.0                2701.0                 0.0
#
#                 total_prisoner_deaths  prisoner_positive_rate  \
# name
# Alabama                           1.0                0.078431
# Alaska                            0.0                0.004255
# Arizona                           5.0                0.249097
# Arkansas                          5.0                0.210908
# California                        1.0                0.256609
# Colorado                          1.0                0.290534
# Connecticut                       6.0                0.210908
# Delaware                          3.0                0.468165
# Florida                           7.0                0.488199
# Georgia                          10.0                0.210908
# Hawaii                            0.0                0.000000
# Idaho                             0.0                0.000000
# Illinois                         12.0                0.293333
# Indiana                          13.0                0.592417
# Iowa                              0.0                0.048499
# Kansas                            3.0                0.210908
# Kentucky                          2.0                0.210908
# Louisiana                         4.0                0.210908
# Maine                             0.0                0.000000
# Maryland                          2.0                0.210908
# Massachusetts                     7.0                0.184155
# Michigan                         47.0                0.255516
# Minnesota                         0.0                0.193925
# Mississippi                       1.0                0.108108
# Missouri                          1.0                0.084211
# Montana                           0.0                0.210908
# Nebraska                          0.0                0.210908
# Nevada                            0.0                0.000000
# New Hampshire                     0.0                0.000000
# New Jersey                       38.0                0.778986
# New Mexico                        0.0                0.000000
# New York                         15.0                0.670436
# North Carolina                    4.0                0.508104
# North Dakota                      0.0                0.000000
# Ohio                             42.0                0.622941
# Oklahoma                          0.0                0.001934
# Oregon                            0.0                0.181070
# Pennsylvania                      3.0                0.437309
# Rhode Island                      0.0                0.036364
# South Carolina                    2.0                0.210908
# South Dakota                      0.0                0.024390
# Tennessee                         1.0                0.328581
# Texas                            23.0                0.626054
# Utah                              0.0                0.099010
# Vermont                           0.0                0.117188
# Virginia                          3.0                0.210908
# Washington                        0.0                0.068571
# West Virginia                     0.0                0.000000
# Wisconsin                         0.0                0.129032
# Wyoming                           0.0                0.000000
# Federal                          42.0                0.210908
#
#                 staff_positive_rate  prisoner_test_prop  staff_test_prop  \
# name
# Alabama                         NaN            0.004822              NaN
# Alaska                          NaN            0.047028              NaN
# Arizona                         NaN            0.006647              NaN
# Arkansas                        NaN                 NaN              NaN
# California                      NaN            0.013092              NaN
# Colorado                        NaN            0.061280              NaN
# Connecticut                     NaN                 NaN              NaN
# Delaware                   0.212625            0.057742         0.118972
# Florida                         NaN            0.008766              NaN
# Georgia                         NaN                 NaN              NaN
# Hawaii                          NaN            0.004319              NaN
# Idaho                      0.073529            0.006151         0.034017
# Illinois                        NaN            0.016258              NaN
# Indiana                    0.263217            0.031386         0.148167
# Iowa                            NaN            0.051541              NaN
# Kansas                          NaN                 NaN              NaN
# Kentucky                        NaN                 NaN              NaN
# Louisiana                       NaN                 NaN              NaN
# Maine                           NaN            0.011392              NaN
# Maryland                        NaN                 NaN              NaN
# Massachusetts                   NaN            0.233207              NaN
# Michigan                        NaN            0.215273              NaN
# Minnesota                       NaN            0.049554              NaN
# Mississippi                0.162791            0.001982         0.072758
# Missouri                        NaN            0.014615              NaN
# Montana                         NaN                 NaN              NaN
# Nebraska                        NaN                 NaN              NaN
# Nevada                          NaN            0.003935              NaN
# New Hampshire                   NaN            0.005343              NaN
# New Jersey                      NaN            0.015255              NaN
# New Mexico                 0.062500            0.002125         0.033809
# New York                        NaN            0.014468              NaN
# North Carolina             0.116000            0.036520         0.032158
# North Dakota               0.025862            0.025723         0.411348
# Ohio                            NaN            0.141946              NaN
# Oklahoma                        NaN            0.042363              NaN
# Oregon                          NaN            0.016807              NaN
# Pennsylvania               0.309002            0.007415         0.027267
# Rhode Island               0.055000            0.048056         0.149365
# South Carolina                  NaN                 NaN              NaN
# South Dakota               0.085106            0.022085         0.078464
# Tennessee                       NaN            0.281891              NaN
# Texas                      0.211854            0.015229         0.065950
# Utah                            NaN            0.016474              NaN
# Vermont                    0.123377            0.273115         0.153846
# Virginia                        NaN                 NaN              NaN
# Washington                      NaN            0.020649              NaN
# West Virginia                   NaN            0.006605              NaN
# Wisconsin                       NaN            0.006860              NaN
# Wyoming                    0.083333            0.007643         0.011662
# Federal                         NaN                 NaN              NaN
#
#                 prisoner_pos_prop  staff_pos_prop  prisoner_affected_prop  \
# name
# Alabama                  0.078431             NaN                0.000378
# Alaska                   0.004255             NaN                0.000200
# Arizona                  0.249097             NaN                0.001656
# Arkansas                      NaN             NaN                0.051922
# California               0.256609             NaN                0.003360
# Colorado                 0.290534             NaN                0.017804
# Connecticut                   NaN             NaN                0.039123
# Delaware                 0.468165        0.212625                0.027033
# Florida                  0.488199             NaN                0.004280
# Georgia                       NaN             NaN                0.005775
# Hawaii                   0.000000             NaN                0.000000
# Idaho                    0.000000        0.073529                0.000000
# Illinois                 0.293333             NaN                0.004769
# Indiana                  0.592417        0.263217                0.018594
# Iowa                     0.048499             NaN                0.002500
# Kansas                        NaN             NaN                0.062184
# Kentucky                      NaN             NaN                0.028858
# Louisiana                     NaN             NaN                0.010693
# Maine                    0.000000             NaN                0.000000
# Maryland                      NaN             NaN                0.003245
# Massachusetts            0.184155             NaN                0.042946
# Michigan                 0.255516             NaN                0.055006
# Minnesota                0.193925             NaN                0.009610
# Mississippi              0.108108        0.162791                0.000214
# Missouri                 0.084211             NaN                0.001231
# Montana                       NaN             NaN                0.000115
# Nebraska                      NaN             NaN                0.000000
# Nevada                   0.000000             NaN                0.000000
# New Hampshire            0.000000             NaN                0.000000
# New Jersey               0.778986             NaN                0.011883
# New Mexico               0.000000        0.062500                0.000000
# New York                 0.670436             NaN                0.009700
# North Carolina           0.508104        0.116000                0.018556
# North Dakota             0.000000        0.025862                0.000000
# Ohio                     0.622941             NaN                0.088424
# Oklahoma                 0.001934             NaN                0.000082
# Oregon                   0.181070             NaN                0.003043
# Pennsylvania             0.437309        0.309002                0.003243
# Rhode Island             0.036364        0.055000                0.001747
# South Carolina                NaN             NaN                0.002363
# South Dakota             0.024390        0.085106                0.000539
# Tennessee                0.328581             NaN                0.092624
# Texas                    0.626054        0.211854                0.009534
# Utah                     0.099010             NaN                0.001631
# Vermont                  0.117188        0.123377                0.032006
# Virginia                      NaN             NaN                0.020309
# Washington               0.068571             NaN                0.001416
# West Virginia            0.000000             NaN                0.000000
# Wisconsin                0.129032             NaN                0.000885
# Wyoming                  0.000000        0.083333                0.000000
# Federal                       NaN             NaN                0.015672
#
#                 staff_affected_prop  prisoner_death_prop  staff_death_prop
# name
# Alabama                    0.002716             0.125000          0.000000
# Alaska                     0.004059             0.000000          0.000000
# Arizona                    0.006092             0.072464          0.000000
# Arkansas                   0.031397             0.005297          0.000000
# California                 0.003674             0.002513          0.000000
# Colorado                   0.003989             0.003226          0.000000
# Connecticut                0.058023             0.012552          0.000000
# Delaware                   0.025296             0.024000          0.000000
# Florida                    0.008102             0.017812          0.000000
# Georgia                    0.011906             0.031646          0.010000
# Hawaii                     0.000000             0.000000          0.000000
# Idaho                      0.002501             0.000000          0.000000
# Illinois                   0.013327             0.068182          0.000000
# Indiana                    0.039000             0.026000          0.008547
# Iowa                       0.004453             0.000000          0.000000
# Kansas                     0.029740             0.004878          0.000000
# Kentucky                   0.013761             0.005882          0.000000
# Louisiana                  0.024707             0.011834          0.025000
# Maine                      0.000884             0.000000          0.000000
# Maryland                   0.033267             0.032787          0.000000
# Massachusetts              0.032272             0.019943          0.000000
# Michigan                   0.024492             0.022672          0.006826
# Minnesota                  0.021641             0.000000          0.000000
# Mississippi                0.011844             0.250000          0.000000
# Missouri                   0.001818             0.031250          0.000000
# Montana                    0.000585             0.000000          0.000000
# Nebraska                   0.002391             0.000000          0.000000
# Nevada                     0.005714             0.000000          0.000000
# New Hampshire              0.013366             0.000000          0.000000
# New Jersey                 0.071767             0.176744          0.003478
# New Mexico                 0.002113             0.000000          0.000000
# New York                   0.059771             0.036145          0.003500
# North Carolina             0.003730             0.006380          0.000000
# North Dakota               0.010638             0.000000          0.000000
# Ohio                       0.039616             0.009740          0.004141
# Oklahoma                   0.002098             0.000000          0.000000
# Oregon                     0.004522             0.000000          0.000000
# Pennsylvania               0.008426             0.020979          0.000000
# Rhode Island               0.008215             0.000000          0.000000
# South Carolina             0.011606             0.047619          0.017857
# South Dakota               0.006678             0.000000          0.000000
# Tennessee                  0.010620             0.000510          0.000000
# Texas                      0.013972             0.017216          0.009921
# Utah                       0.001769             0.000000          0.000000
# Vermont                    0.018981             0.000000          0.000000
# Virginia                   0.007307             0.005172          0.000000
# Washington                 0.003975             0.000000          0.000000
# West Virginia              0.000664             0.000000          0.000000
# Wisconsin                  0.004957             0.000000          0.000000
# Wyoming                    0.000972             0.000000          0.000000
# Federal                    0.014041             0.015550          0.000000

# %%
prison_covid['prisoner_positive_rate'] = prison_covid['total_prisoner_cases']/prison_covid['prisoner_tests']
prison_covid['prisoner_positive_rate'].fillna(prison_covid['prisoner_positive_rate'].mean(), inplace=True)

# %%
prison_covid['prisoner_test_prop'] = prison_covid['prisoner_tests']/prison_covid['prison_pop']
prison_covid['staff_test_prop'] = prison_covid['staff_tests']/prison_covid['staff_pop']

# %%
prison_covid['prisoner_pos_prop'] = prison_covid['total_prisoner_cases']/prison_covid['prisoner_tests']
prison_covid['staff_pos_prop'] = prison_covid['total_staff_cases']/prison_covid['staff_tests']

prison_covid['prisoner_affected_prop'] = prison_covid['total_prisoner_cases']/prison_covid['prison_pop']
prison_covid['staff_affected_prop'] = prison_covid['total_staff_cases']/prison_covid['staff_pop']

prison_covid['prisoner_death_prop'] = prison_covid['total_prisoner_deaths']/prison_covid['total_prisoner_cases']
prison_covid['staff_death_prop'] = prison_covid['total_staff_deaths']/prison_covid['total_staff_cases']

# %%
prison_covid['prisoner_death_prop'].fillna(0, inplace=True)
prison_covid['staff_death_prop'].fillna(0, inplace=True)

# %%
prison_covid['staff_positive_rate'] = prison_covid['total_staff_cases']/prison_covid['staff_tests']
# prison_covid['prisoner_positive_rate'].fillna(prison_covid['prisoner_positive_rate'].mean(), inplace=True)

# %% [markdown]
# ## Classification

# %%
#X = prison_covid
X = lately_covid
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# %%
X_std = prison_covid[['prisoner_positive_rate','prisoner_affected_prop','staff_affected_prop','prisoner_death_prop','staff_death_prop']]

# %%
sum_of_distances = {}
for num_clusters in range(1,16):
    kmeans = KMeans(n_clusters=num_clusters, random_state=1)
    kmeans.fit(X_std)
    sum_of_distances[num_clusters] = kmeans.inertia_
pd.Series(sum_of_distances).sort_index().plot()
plt.xlabel('Number of clusters')
plt.ylabel('Sum of distances of points to closest cluster centers')
plt.show()

# %%
sum_of_distances
# Out:
# {1: 2.154440979200546,
#  2: 0.6841991683843935,
#  3: 0.3041286861852251,
#  4: 0.2240538390204153,
#  5: 0.1549274790357733,
#  6: 0.11624329215948559,
#  7: 0.08515415636559032,
#  8: 0.06054592592035897,
#  9: 0.051837021340922815,
#  10: 0.04354249118090342,
#  11: 0.036965246850805246,
#  12: 0.03190788194450159,
#  13: 0.027662004105598256,
#  14: 0.024074774523510235,
#  15: 0.021250875260954517}

# %%
model = KMeans(n_clusters=3, random_state=1)
model.fit(X_std)

lately_covid['classified_result'] = model.labels_
lately_covid['classified_result'].value_counts()
# Out:
# 1    21
# 0    21
# 2     9
# Name: classified_result, dtype: int64

# %%
lately_covid['classified_result'] = model.predict(X_std)

# %%
X_std[lately_covid['classified_result'] == 0]
# Out:
#                 prisoner_positive_rate  prisoner_affected_prop  \
# name
# Arizona                       0.249097                0.001656
# Arkansas                      0.210908                0.051922
# California                    0.256609                0.003360
# Colorado                      0.290534                0.017804
# Connecticut                   0.210908                0.039123
# Georgia                       0.210908                0.005775
# Illinois                      0.293333                0.004769
# Kansas                        0.210908                0.062184
# Kentucky                      0.210908                0.028858
# Louisiana                     0.210908                0.010693
# Maryland                      0.210908                0.003245
# Massachusetts                 0.184155                0.042946
# Michigan                      0.255516                0.055006
# Minnesota                     0.193925                0.009610
# Montana                       0.210908                0.000115
# Nebraska                      0.210908                0.000000
# Oregon                        0.181070                0.003043
# South Carolina                0.210908                0.002363
# Tennessee                     0.328581                0.092624
# Virginia                      0.210908                0.020309
# Federal                       0.210908                0.015672
#
#                 staff_affected_prop  prisoner_death_prop  staff_death_prop
# name
# Arizona                    0.006092             0.072464          0.000000
# Arkansas                   0.031397             0.005297          0.000000
# California                 0.003674             0.002513          0.000000
# Colorado                   0.003989             0.003226          0.000000
# Connecticut                0.058023             0.012552          0.000000
# Georgia                    0.011906             0.031646          0.010000
# Illinois                   0.013327             0.068182          0.000000
# Kansas                     0.029740             0.004878          0.000000
# Kentucky                   0.013761             0.005882          0.000000
# Louisiana                  0.024707             0.011834          0.025000
# Maryland                   0.033267             0.032787          0.000000
# Massachusetts              0.032272             0.019943          0.000000
# Michigan                   0.024492             0.022672          0.006826
# Minnesota                  0.021641             0.000000          0.000000
# Montana                    0.000585             0.000000          0.000000
# Nebraska                   0.002391             0.000000          0.000000
# Oregon                     0.004522             0.000000          0.000000
# South Carolina             0.011606             0.047619          0.017857
# Tennessee                  0.010620             0.000510          0.000000
# Virginia                   0.007307             0.005172          0.000000
# Federal                    0.014041             0.015550          0.000000

# %%
X_std[lately_covid['classified_result'] == 1]
# Out:
#                prisoner_positive_rate  prisoner_affected_prop  \
# name
# Alabama                      0.078431                0.000378
# Alaska                       0.004255                0.000200
# Hawaii                       0.000000                0.000000
# Idaho                        0.000000                0.000000
# Iowa                         0.048499                0.002500
# Maine                        0.000000                0.000000
# Mississippi                  0.108108                0.000214
# Missouri                     0.084211                0.001231
# Nevada                       0.000000                0.000000
# New Hampshire                0.000000                0.000000
# New Mexico                   0.000000                0.000000
# North Dakota                 0.000000                0.000000
# Oklahoma                     0.001934                0.000082
# Rhode Island                 0.036364                0.001747
# South Dakota                 0.024390                0.000539
# Utah                         0.099010                0.001631
# Vermont                      0.117188                0.032006
# Washington                   0.068571                0.001416
# West Virginia                0.000000                0.000000
# Wisconsin                    0.129032                0.000885
# Wyoming                      0.000000                0.000000
#
#                staff_affected_prop  prisoner_death_prop  staff_death_prop
# name
# Alabama                   0.002716              0.12500               0.0
# Alaska                    0.004059              0.00000               0.0
# Hawaii                    0.000000              0.00000               0.0
# Idaho                     0.002501              0.00000               0.0
# Iowa                      0.004453              0.00000               0.0
# Maine                     0.000884              0.00000               0.0
# Mississippi               0.011844              0.25000               0.0
# Missouri                  0.001818              0.03125               0.0
# Nevada                    0.005714              0.00000               0.0
# New Hampshire             0.013366              0.00000               0.0
# New Mexico                0.002113              0.00000               0.0
# North Dakota              0.010638              0.00000               0.0
# Oklahoma                  0.002098              0.00000               0.0
# Rhode Island              0.008215              0.00000               0.0
# South Dakota              0.006678              0.00000               0.0
# Utah                      0.001769              0.00000               0.0
# Vermont                   0.018981              0.00000               0.0
# Washington                0.003975              0.00000               0.0
# West Virginia             0.000664              0.00000               0.0
# Wisconsin                 0.004957              0.00000               0.0
# Wyoming                   0.000972              0.00000               0.0

# %%
X_std[lately_covid['classified_result'] == 2]
# Out:
#                 prisoner_positive_rate  prisoner_affected_prop  \
# name
# Delaware                      0.468165                0.027033
# Florida                       0.488199                0.004280
# Indiana                       0.592417                0.018594
# New Jersey                    0.778986                0.011883
# New York                      0.670436                0.009700
# North Carolina                0.508104                0.018556
# Ohio                          0.622941                0.088424
# Pennsylvania                  0.437309                0.003243
# Texas                         0.626054                0.009534
#
#                 staff_affected_prop  prisoner_death_prop  staff_death_prop
# name
# Delaware                   0.025296             0.024000          0.000000
# Florida                    0.008102             0.017812          0.000000
# Indiana                    0.039000             0.026000          0.008547
# New Jersey                 0.071767             0.176744          0.003478
# New York                   0.059771             0.036145          0.003500
# North Carolina             0.003730             0.006380          0.000000
# Ohio                       0.039616             0.009740          0.004141
# Pennsylvania               0.008426             0.020979          0.000000
# Texas                      0.013972             0.017216          0.009921
